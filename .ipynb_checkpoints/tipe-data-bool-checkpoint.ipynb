# %% [markdown]
# # Tipe Data Boolean
#
# Tipe data boolean adalah tipe data yang menyatakan benar(True) atau salah(False).

# %%
benar = True

print(benar)
print(type(benar))
# Out:
# True
# <class 'bool'>

# %%
salah = False

print(salah)
print(type(salah))
# Out:
# False
# <class 'bool'>
